// %%
TCanvas c;
TH1F h("h","ROOT Histo;X;Y",64,-4,4);
h.FillRandom("gaus");
h.Draw();
c.Draw();

// %%
.demo
// Out:
// input_line_49:2:2: error: expected expression
//  .demo
//  ^

// %%
demo
// Out:
// input_line_51:2:3: error: use of undeclared identifier 'demo'
//  (demo)
//   ^
// Error in <HandleInterpreterException>: Error evaluating expression (demo).
// Execution of your code was aborted.

// %%
help
// Out:
// input_line_53:2:3: error: use of undeclared identifier 'help'
//  (help)
//   ^
// Error in <HandleInterpreterException>: Error evaluating expression (help).
// Execution of your code was aborted.
